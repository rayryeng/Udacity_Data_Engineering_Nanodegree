# %%
# %load_ext sql

# %%
import configparser
config = configparser.ConfigParser()
config.read('dwh.cfg')

DWH_DB_USER = config.get("CLUSTER", "DB_USER")
DWH_DB_PASSWORD = config.get("CLUSTER", "DB_PASSWORD")
DWH_ENDPOINT = config.get("CLUSTER", "HOST")
DWH_PORT = config.get("CLUSTER", "DB_PORT")
DWH_DB = config.get("CLUSTER", "DB_NAME")

# %%
conn_string="postgresql://{}:{}@{}:{}/{}".format(DWH_DB_USER, DWH_DB_PASSWORD, DWH_ENDPOINT, DWH_PORT, DWH_DB)
print(conn_string)
# Out:
# postgresql://awsuser:Passw0rd@redshift-cluster.csdggmxqwztn.us-east-1.redshift.amazonaws.com:5439/dev

# %%
# %sql $conn_string
# Out:
# 'Connected: awsuser@dev'

# %%
# %sql SELECT * FROM songplays LIMIT 20;
# Out:
#  * postgresql://awsuser:***@redshift-cluster.csdggmxqwztn.us-east-1.redshift.amazonaws.com:5439/dev
# 20 rows affected.
# [(1, datetime.datetime(2018, 11, 9, 17, 55), 80, 'paid', 'SOAOJYY12A58A7B2F9', 'ARFVYJI1187B9B8E13', 416, 'Portland-South Portland, ME', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (2, datetime.datetime(2018, 11, 8, 15, 1, 57), 29, 'paid', 'SOFVOQL12A6D4F7456', 'ARPN0Y61187B9ABAA0', 372, 'Atlanta-Sandy Springs-Roswell, GA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.78.2 (KHTML, like Gecko) Version/7.0.6 Safari/537.78.2"'),
#  (5, datetime.datetime(2018, 11, 13, 17, 28, 33), 97, 'paid', 'SOIBHYW12AB0188F49', 'ARWNARC122BCFCAFEB', 537, 'Lansing-East Lansing, MI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36"'),
# ...

# %%
# %sql SELECT * FROM users LIMIT 20;
# Out:
#  * postgresql://awsuser:***@redshift-cluster.csdggmxqwztn.us-east-1.redshift.amazonaws.com:5439/dev
# 20 rows affected.
# [(48, 'Marina', 'Sutton', 'F', 'free'),
#  (17, 'Makinley', 'Jones', 'F', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free'),
#  (26, 'Ryan', 'Smith', 'M', 'free'),
#  (53, 'Celeste', 'Williams', 'F', 'free'),
#  (69, 'Anabelle', 'Simpson', 'F', 'free'),
#  (80, 'Tegan', 'Levine', 'F', 'free'),
#  (88, 'Mohammad', 'Rodriguez', 'M', 'free'),
#  (49, 'Chloe', 'Cuevas', 'F', 'free'),
#  (100, 'Adler', 'Barrera', 'M', 'free'),
#  (61, 'Samuel', 'Gonzalez', 'M', 'free'),
#  (75, 'Joseph', 'Gutierrez', 'M', 'free'),
#  (50, 'Ava', 'Robinson', 'F', 'free'),
#  (12, 'Austin', 'Rosales', 'M', 'free'),
#  (71, 'Ayleen', 'Wise', 'F', 'free'),
#  (3, 'Isaac', 'Valdez', 'M', 'free'),
#  (99, 'Ann', 'Banks', 'F', 'free'),
#  (43, 'Jahiem', 'Miles', 'M', 'free'),
#  (6, 'Cecilia', 'Owens', 'F', 'free'),
#  (51, 'Maia', 'Burke', 'F', 'free')]

# %%
# %sql SELECT * FROM songs LIMIT 20;
# Out:
#  * postgresql://awsuser:***@redshift-cluster.csdggmxqwztn.us-east-1.redshift.amazonaws.com:5439/dev
# 20 rows affected.
# [('SOBRKGM12A8C139EF6', 'Welcome to the Pleasuredome', 'ARXQBR11187B98A2CC', 1985, 821.05424),
#  ('SOVROYO12AB0186D09', 'Blood In Face', 'ARCZBX11187B9AD089', 2000, 287.29424),
#  ('SOGMORP12A8C13EF63', 'Auburn and Ivory', 'ARWCIEL1187FB42EF5', 2006, 270.00118),
#  ('SODVVEL12A6D4F9EA0', 'Good Old Wagon (LP Version)', 'ARI9DQS1187B995625', 1964, 139.78077),
#  ('SOJCRUY12A67ADA4C2', 'Fast Car (LP Version)', 'ARAO91X1187B98CCA4', 1988, 296.07138),
#  ('SOJYPBE12A58A7A994', 'Astair', 'ARIQ98H1187B98DFBC', 2003, 178.83383),
#  ('SOLRYQR12A670215BF', 'Panama (Remastered Album Version)', 'ARNLO5S1187B9B80CC', 0, 209.29261),
#  ('SOCHRXB12A8AE48069', "Let's Get It Started", 'ARTDQRC1187FB4EFD4', 2004, 229.61587),
#  ('SOOTBYV12AB0186EC8', 'Gold', 'ARNULK21187FB46537', 1988, 260.91057),
# ...

# %%
# %sql SELECT * FROM artists LIMIT 20;
# Out:
#  * postgresql://awsuser:***@redshift-cluster.csdggmxqwztn.us-east-1.redshift.amazonaws.com:5439/dev
# 20 rows affected.
# [('AREWD471187FB49873', 'Son Kite', None, None, None),
#  ('ARCLYBR1187FB53913', 'Neal Schon', 'San Mateo, CA', 37.54703, -122.31483),
#  ('AR1LOGZ1187B990FB4', 'Mike Stern', 'Boston, MA', None, None),
#  ('AR1S3NH1187B98C2BC', 'Anthony B', 'Clarks Town, Jamaica', None, None),
#  ('AR9E1QW1187B999A34', 'Mikel Erentxun', None, None, None),
#  ('ARCTL0M1187FB5CEC7', 'MRK 1', None, None, None),
#  ('ARDNS031187B9924F0', 'Tim Wilson', 'Georgia', 32.67828, -83.22295),
#  ('ARBJ3VU1187B9B472D', 'Love Of Lesbian', None, None, None),
#  ('ARPQ4Z01187FB3A736', 'Butthole Surfers', 'San Antonio, TX', 29.42449, -98.49462),
#  ('ARV1JVD1187B9AD195', 'Loudon Wainwright III', 'Chapel Hill, NC', 35.91463, -79.05661),
#  ('ARMI4NV1187B99D55D', 'Man Man', 'Philadelphia, PA', 39.95227, -75.16237),
#  ('ARHAJH611C8A4219F1', "La Bottega Dell'Arte", None, None, None),
# ...

# %%
# %sql SELECT * FROM time LIMIT 20;
# Out:
#  * postgresql://awsuser:***@redshift-cluster.csdggmxqwztn.us-east-1.redshift.amazonaws.com:5439/dev
# 20 rows affected.
# [(datetime.datetime(2018, 11, 1, 21, 11, 13), 21, 1, 44, 11, 2018, 4),
#  (datetime.datetime(2018, 11, 2, 18, 36, 53), 18, 2, 44, 11, 2018, 5),
#  (datetime.datetime(2018, 11, 4, 6, 51, 12), 6, 4, 44, 11, 2018, 0),
#  (datetime.datetime(2018, 11, 4, 7, 31, 31), 7, 4, 44, 11, 2018, 0),
#  (datetime.datetime(2018, 11, 4, 9, 19, 3), 9, 4, 44, 11, 2018, 0),
#  (datetime.datetime(2018, 11, 4, 9, 41, 55), 9, 4, 44, 11, 2018, 0),
#  (datetime.datetime(2018, 11, 4, 15, 39, 36), 15, 4, 44, 11, 2018, 0),
#  (datetime.datetime(2018, 11, 4, 16, 25, 54), 16, 4, 44, 11, 2018, 0),
#  (datetime.datetime(2018, 11, 5, 1, 58, 24), 1, 5, 45, 11, 2018, 1),
#  (datetime.datetime(2018, 11, 5, 2, 9, 47), 2, 5, 45, 11, 2018, 1),
#  (datetime.datetime(2018, 11, 5, 5, 57, 5), 5, 5, 45, 11, 2018, 1),
#  (datetime.datetime(2018, 11, 5, 11, 14), 11, 5, 45, 11, 2018, 1),
# ...

# %%
# %sql SELECT * FROM songplays WHERE song_id IS NOT NULL and artist_id IS NOT NULL LIMIT 20;
# Out:
#  * postgresql://awsuser:***@redshift-cluster.csdggmxqwztn.us-east-1.redshift.amazonaws.com:5439/dev
# 20 rows affected.
# [(0, datetime.datetime(2018, 11, 21, 21, 56, 47), 15, 'paid', 'SOZCTXZ12AB0182364', 'AR5KOSW1187FB35FF4', 818, 'Chicago-Naperville-Elgin, IL-IN-WI', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (3, datetime.datetime(2018, 11, 3, 21, 14, 28), 49, 'free', 'SOFVOQL12A6D4F7456', 'ARPN0Y61187B9ABAA0', 195, 'San Francisco-Oakland-Hayward, CA', 'Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0'),
#  (4, datetime.datetime(2018, 11, 26, 15, 33, 56), 72, 'paid', 'SODOLVO12B0B80B2F4', 'AR6XPWV1187B9ADAEB', 381, 'Detroit-Warren-Dearborn, MI', 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:30.0) Gecko/20100101 Firefox/30.0'),
# ...

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to Amazon Redshift
# Each time you run the cells above, remember to restart this notebook to close the connection to your database.
